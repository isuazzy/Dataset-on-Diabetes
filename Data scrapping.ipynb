# %% [markdown]
# Scrapping data from a real website + pandas

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\DELL\\Downloads\\google (1).csv')

# %%
df
# Out:
#                                                 TrmO7              bNg8Rb  \
# 0   .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN      Search Results
# ..                                                ...                 ...
# 90                                                NaN        Footer links
# 91  .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 92                                                NaN                 NaN
# 93                                                NaN      Search Results
# 94                                                NaN        Footer links
#
#    YmvwI                                         nPDzT href YmvwI 2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Columns: 150 entries, TrmO7 to ylgVCe 19
# dtypes: float64(9), object(141)
# memory usage: 111.5+ KB

# %%
df.isnull().sum()
# Out:
# TrmO7           72
# bNg8Rb          26
# YmvwI           72
# nPDzT href      72
# YmvwI 2         72
#                 ..
# Fx4vi href 3    72
# Fx4vi 4         72
# Fx4vi href 4    72
# ylgVCe 11       74
# ylgVCe 19       75
# Length: 150, dtype: int64

# %%
df.interpolate()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_6324\4002874584.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate()
#                                                 TrmO7              bNg8Rb  \
# 0   .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN      Search Results
# ..                                                ...                 ...
# 90                                                NaN        Footer links
# 91  .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# ...

# %%
df.mean
# Out:
# <bound method DataFrame.mean of                                                 TrmO7              bNg8Rb  \
# 0   .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN      Search Results
# ..                                                ...                 ...
# 90                                                NaN        Footer links
# 91  .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 92                                                NaN                 NaN
# 93                                                NaN      Search Results
# 94                                                NaN        Footer links
#
# ...

# %%
df.median
# Out:
# <bound method DataFrame.median of                                                 TrmO7              bNg8Rb  \
# 0   .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN      Search Results
# ..                                                ...                 ...
# 90                                                NaN        Footer links
# 91  .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 92                                                NaN                 NaN
# 93                                                NaN      Search Results
# 94                                                NaN        Footer links
#
# ...

# %%
df
# Out:
#                                                 TrmO7              bNg8Rb  \
# 0   .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN      Search Results
# ..                                                ...                 ...
# 90                                                NaN        Footer links
# 91  .T7Ko6{flex-direction:row;display:flex;align-i...  Filters and topics
# 92                                                NaN                 NaN
# 93                                                NaN      Search Results
# 94                                                NaN        Footer links
#
#    YmvwI                                         nPDzT href YmvwI 2  \
# ...

# %%
sns.countplot(x= 'bNg8Rb', data = df)
# Out:
# <Axes: xlabel='bNg8Rb', ylabel='count'>
