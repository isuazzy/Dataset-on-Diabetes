# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/european-football-matches/Liga Portugal.csv
# /kaggle/input/european-football-matches/Bundesliga.csv
# /kaggle/input/european-football-matches/Greek Super League.csv
# /kaggle/input/european-football-matches/English Premier League.csv
# /kaggle/input/european-football-matches/La Liga.csv
# /kaggle/input/european-football-matches/Scottish Division 1.csv
# /kaggle/input/european-football-matches/Ligue 2.csv
# /kaggle/input/european-football-matches/Serie B.csv
# /kaggle/input/european-football-matches/English Championship.csv
# /kaggle/input/european-football-matches/Scottish Premier League.csv
# /kaggle/input/european-football-matches/Scottish Division 3.csv
# /kaggle/input/european-football-matches/Bundesliga 2.csv
# /kaggle/input/european-football-matches/Ligue 1.csv
# /kaggle/input/european-football-matches/Serie A.csv
# /kaggle/input/european-football-matches/combined_matches.csv
# /kaggle/input/european-football-matches/English League 2.csv
# ...

# %%
df= pd.read_csv('/kaggle/input/european-football-matches/English League 1.csv')

# %%
df
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result
# 0            2.0      A
# ...

# %%
information showing the results of the match

# %%
df.info
# Out:
# <bound method DataFrame.info of                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result
# ...

# %%
describing the mean,median,standard deviation ...e.t.c

# %%
df.describe()
# Out:
#           HomeGoals     AwayGoals
# count  16408.000000  16408.000000
# mean       1.459837      1.137250
# std        1.215479      1.077621
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max        8.000000      8.000000

# %%
checking for any missing value

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
# ...

# %%
creating a new column called (new)

# %%
df['new'] = df['HomeGoals']* df ['AwayGoals']

# %%
df
# Out:
#                  League        Date        HomeTeam     AwayTeam  HomeGoals  \
# 0      English League 1    14/08/93          Barnet         Hull        1.0
# 1      English League 1    14/08/93        Bradford     Brighton        2.0
# 2      English League 1    14/08/93       Brentford       Exeter        2.0
# 3      English League 1    14/08/93     Bristol Rvs  Bournemouth        0.0
# 4      English League 1    14/08/93         Burnley    Port Vale        2.0
# ...                 ...         ...             ...          ...        ...
# 16403  English League 1  07/05/2023         Lincoln   Shrewsbury        1.0
# 16404  English League 1  07/05/2023          Oxford   Accrington        1.0
# 16405  English League 1  07/05/2023       Port Vale     Plymouth        1.0
# 16406  English League 1  07/05/2023      Portsmouth      Wycombe        2.0
# 16407  English League 1  07/05/2023  Sheffield Weds        Derby        1.0
#
#        AwayGoals Result  new
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.stripplot(y='HomeGoals', x='AwayGoals', data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='AwayGoals', ylabel='HomeGoals'>

# %%
sns.displot(data = df, x = 'HomeGoals')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
